# %% [markdown]
# <a href="https://colab.research.google.com/github/clusterchamps/Masters/blob/M5-Forcasting/M5_Forecasting_Akshay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
sell_prices = pd.read_csv('/content/drive/My Drive/m5-forecasting-uncertainty/sell_prices.csv')

# %%
sell_prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
sell_prices.shape
# Out:
# (6841121, 4)

# %%
sales_train_validation = pd.read_csv('/content/drive/My Drive/m5-forecasting-uncertainty/sales_train_validation.csv')

# %%
sales_train_validation.head()
# Out:
#                               id        item_id  ... d_1912 d_1913
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  ...      1      1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  ...      0      0
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  ...      1      1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  ...      7      2
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  ...      2      4
#
# [5 rows x 1919 columns]

# %%
sales_train_validation.shape
# Out:
# (30490, 1919)

# %%
calendar = pd.read_csv('/content/drive/My Drive/m5-forecasting-uncertainty/calendar.csv')

# %%
calendar.head(10)
# Out:
#          date  wm_yr_wk    weekday  ...  snap_CA  snap_TX  snap_WI
# 0  2011-01-29     11101   Saturday  ...        0        0        0
# 1  2011-01-30     11101     Sunday  ...        0        0        0
# 2  2011-01-31     11101     Monday  ...        0        0        0
# 3  2011-02-01     11101    Tuesday  ...        1        1        0
# 4  2011-02-02     11101  Wednesday  ...        1        0        1
# 5  2011-02-03     11101   Thursday  ...        1        1        1
# 6  2011-02-04     11101     Friday  ...        1        0        0
# 7  2011-02-05     11102   Saturday  ...        1        1        1
# 8  2011-02-06     11102     Sunday  ...        1        1        1
# 9  2011-02-07     11102     Monday  ...        1        1        0
#
# [10 rows x 14 columns]

# %%
calendar.shape
# Out:
# (1969, 14)

# %%
sample_submission = pd.read_csv('/content/drive/My Drive/m5-forecasting-uncertainty/sample_submission.csv')

# %%
sample_submission.shape
# Out:
# (771120, 29)

# %%
sales_train_validation.isnull().sum()
# Out:
# id          0
# item_id     0
# dept_id     0
# cat_id      0
# store_id    0
#            ..
# d_1909      0
# d_1910      0
# d_1911      0
# d_1912      0
# d_1913      0
# Length: 1919, dtype: int64

# %%
calendar.isnull().sum()
# Out:
# date               0
# wm_yr_wk           0
# weekday            0
# wday               0
# month              0
# year               0
# d                  0
# event_name_1    1807
# event_type_1    1807
# event_name_2    1964
# event_type_2    1964
# snap_CA            0
# snap_TX            0
# snap_WI            0
# dtype: int64

# %%
sell_prices.isnull().sum()
# Out:
# store_id      0
# item_id       0
# wm_yr_wk      0
# sell_price    0
# dtype: int64

# %%
cal1 = calendar.copy()

# %%
cal1.drop(['event_name_1','event_type_1',	'event_name_2',	'event_type_2'])
# Out:
#             date  wm_yr_wk    weekday  wday  ...       d  snap_CA snap_TX  snap_WI
# 0     2011-01-29     11101   Saturday     1  ...     d_1        0       0        0
# 1     2011-01-30     11101     Sunday     2  ...     d_2        0       0        0
# 2     2011-01-31     11101     Monday     3  ...     d_3        0       0        0
# 3     2011-02-01     11101    Tuesday     4  ...     d_4        1       1        0
# 4     2011-02-02     11101  Wednesday     5  ...     d_5        1       0        1
# ...          ...       ...        ...   ...  ...     ...      ...     ...      ...
# 1964  2016-06-15     11620  Wednesday     5  ...  d_1965        0       1        1
# 1965  2016-06-16     11620   Thursday     6  ...  d_1966        0       0        0
# 1966  2016-06-17     11620     Friday     7  ...  d_1967        0       0        0
# 1967  2016-06-18     11621   Saturday     1  ...  d_1968        0       0        0
# ...

# %%
plt.plot(cal1.corr())
